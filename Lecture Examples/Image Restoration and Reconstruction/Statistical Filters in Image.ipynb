# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal, ndimage
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import mean_squared_error as mse
import seaborn as sns

# %%
def create_test_image(size=128):
    """Create a test image with three intensity levels and a circle pattern."""
    img = np.ones((size, size)) * 0.5
    center = size // 2
    y, x = np.ogrid[-center:size-center, -center:size-center]

    mask_outer = x*x + y*y <= (size//3)**2
    img[mask_outer] = 0.75

    mask_inner = x*x + y*y <= (size//4)**2
    img[mask_inner] = 1.0

    return img

def add_noise(image, noise_type, params):
    """Add different types of noise to the image."""
    noisy = image.copy()
    if noise_type == 'gaussian':
        noise = np.random.normal(0, params['sigma'], image.shape)
        noisy = image + noise
    elif noise_type == 'salt':
        mask = np.random.random(image.shape) < params['prob']
        noisy[mask] = 1.0
    elif noise_type == 'pepper':
        mask = np.random.random(image.shape) < params['prob']
        noisy[mask] = 0.0
    elif noise_type == 'salt_and_pepper':
        mask = np.random.random(image.shape) < params['prob']/2
        noisy[mask] = 1.0
        mask = np.random.random(image.shape) < params['prob']/2
        noisy[mask] = 0.0

    return np.clip(noisy, 0, 1)

def median_filter(image, kernel_size):
    """Apply median filter."""
    return ndimage.median_filter(image, size=kernel_size)

def max_filter(image, kernel_size):
    """Apply maximum filter."""
    return ndimage.maximum_filter(image, size=kernel_size)

def min_filter(image, kernel_size):
    """Apply minimum filter."""
    return ndimage.minimum_filter(image, size=kernel_size)

def alpha_trimmed_mean_filter(image, kernel_size, alpha):
    """Apply alpha-trimmed mean filter."""
    pad_width = kernel_size // 2
    padded = np.pad(image, pad_width, mode='symmetric')
    result = np.zeros_like(image)

    for i in range(image.shape[0]):
        for j in range(image.shape[1]):
            window = padded[i:i+kernel_size, j:j+kernel_size].flatten()
            trimmed_size = int(alpha * len(window))
            sorted_window = np.sort(window)[trimmed_size:-trimmed_size]
            result[i, j] = np.mean(sorted_window)

    return result

def midpoint_filter(image, kernel_size):
    """Apply midpoint filter (average of min and max)."""
    max_val = ndimage.maximum_filter(image, size=kernel_size)
    min_val = ndimage.minimum_filter(image, size=kernel_size)
    return (max_val + min_val) / 2

def calculate_metrics(original, filtered):
    """Calculate multiple image quality metrics."""
    return {
        'PSNR': psnr(original, filtered, data_range=1.0),
        'SSIM': ssim(original, filtered, data_range=1.0),
        'MSE': mse(original, filtered),
        'MAE': np.mean(np.abs(original - filtered))
    }

# %%
def run_experiments():
    # Create original image
    original = create_test_image()
    kernel_size = 3

    # Define noise parameters
    noise_params = {
        'gaussian': {'sigma': 0.1},
        'salt': {'prob': 0.1},
        'pepper': {'prob': 0.1},
        'salt_and_pepper': {'prob': 0.1}
    }

    # Define filters
    filters = {
        'Median': lambda img: median_filter(img, kernel_size),
        'Maximum': lambda img: max_filter(img, kernel_size),
        'Minimum': lambda img: min_filter(img, kernel_size),
        'Alpha-Trimmed\n(α=0.2)': lambda img: alpha_trimmed_mean_filter(img, kernel_size, 0.2),
        'Midpoint': lambda img: midpoint_filter(img, kernel_size)
    }

    # Store results
    results = {}

    # Create a figure for all noise types with spacing
    fig = plt.figure(figsize=(20, 16))
    gs = fig.add_gridspec(len(noise_params), 1, height_ratios=[1]*len(noise_params), hspace=0.4)

    # Run experiments for each noise type
    for noise_idx, (noise_type, params) in enumerate(noise_params.items()):
        # Create noisy image
        noisy = add_noise(original, noise_type, params)

        # Apply filters and calculate metrics
        noise_results = {}
        for filter_name, filter_func in filters.items():
            filtered = filter_func(noisy)
            metrics = calculate_metrics(original, filtered)
            noise_results[filter_name] = metrics

        results[noise_type] = noise_results

        # Create subplot for this noise type
        inner_gs = gs[noise_idx].subgridspec(1, 7, wspace=0.3)
        axes = [fig.add_subplot(inner_gs[0, i]) for i in range(7)]

        plt.suptitle('Order-Statistic Filters Comparison', fontsize=16, y=0.95)

        # Plot original and noisy images
        axes[0].imshow(original, cmap='gray', vmin=0, vmax=1)
        axes[0].set_title('Original', fontsize=10)
        axes[0].axis('off')

        axes[1].imshow(noisy, cmap='gray', vmin=0, vmax=1)
        axes[1].set_title(f'Noisy\n({noise_type.replace("_", " ").title()})', fontsize=10)
        axes[1].axis('off')

        # Plot filtered images
        for idx, (filter_name, filter_func) in enumerate(filters.items()):
            filtered = filter_func(noisy)
            axes[idx+2].imshow(filtered, cmap='gray', vmin=0, vmax=1)
            axes[idx+2].set_title(f'{filter_name}\nPSNR: {results[noise_type][filter_name]["PSNR"]:.2f}',
                              fontsize=8)
            axes[idx+2].axis('off')

    plt.tight_layout()
    plt.show()

    # Create heatmap comparison for all metrics
    metrics = ['PSNR', 'SSIM', 'MSE', 'MAE']
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    fig.suptitle('Performance Metrics Comparison', fontsize=14)

    for idx, metric in enumerate(metrics):
        ax = axes[idx//2, idx%2]
        data = np.zeros((len(noise_params), len(filters)))

        for i, noise_type in enumerate(noise_params.keys()):
            for j, filter_name in enumerate(filters.keys()):
                data[i, j] = results[noise_type][filter_name][metric]

        sns.heatmap(data,
                   ax=ax,
                   xticklabels=list(filters.keys()),
                   yticklabels=list(noise_params.keys()),
                   annot=True, fmt='.2f', cmap='viridis')

        ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=8)
        ax.set_yticklabels(ax.get_yticklabels(), fontsize=8)
        ax.set_title(f'{metric} Comparison')

    plt.tight_layout()
    plt.show()

    return results

# %%
# Run experiments and get results
results = run_experiments()
# Out:
# <ipython-input-3-9ac1abc63ea5>:67: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Print analysis summary
print("\nFilter Performance Analysis:")
print("\nMedian Filter:")
print("- Best for salt & pepper noise")
print("- Preserves edges better than mean filters")
print("- Good all-around performance")

print("\nMaximum Filter:")
print("- Effective for pepper noise")
print("- Tends to brighten images")
print("- Can expand bright regions")

print("\nMinimum Filter:")
print("- Effective for salt noise")
print("- Tends to darken images")
print("- Can expand dark regions")

print("\nAlpha-Trimmed Mean Filter:")
print("- Combines properties of mean and median filters")
print("- Good for mixed noise types")
print("- Performance depends on alpha value")

print("\nMidpoint Filter:")
print("- Combines max and min operations")
print("- Good for uniformly distributed noise")
print("- Can preserve brightness better than median")
# Out:
# Filter Performance Analysis:
#
# Median Filter:
# - Best for salt & pepper noise
# - Preserves edges better than mean filters
# - Good all-around performance
#
# Maximum Filter:
# - Effective for pepper noise
# - Tends to brighten images
# - Can expand bright regions
#
# Minimum Filter:
# - Effective for salt noise
# - Tends to darken images
# - Can expand dark regions
#
# Alpha-Trimmed Mean Filter:
# - Combines properties of mean and median filters
# - Good for mixed noise types
# - Performance depends on alpha value
#
# Midpoint Filter:
# - Combines max and min operations
# - Good for uniformly distributed noise
# - Can preserve brightness better than median
